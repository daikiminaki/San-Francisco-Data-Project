# %% [markdown]
# # What is San Francisco - Businesses EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()
import datetime

import glob as glob

# %% [markdown]
# ## Table of Contents

# %%
glob.glob('../data/Businesses/*.csv')
# Out:
# ['../data/Businesses/Community_Development_Public_Service_Program_Activities_by_Neighborhood.csv',
#  '../data/Businesses/Mobile_Food_Facility_Permit.csv',
#  '../data/Businesses/sf_business_data_clean.csv',
#  '../data/Businesses/Registered_Business_Locations_-_San_Francisco.csv',
#  '../data/Businesses/Active_Business_Locations.csv',
#  '../data/Businesses/Mobile_Food_Schedule.csv',
#  '../data/Businesses/Registered_Business_Locations.csv',
#  '../data/Businesses/Registered_Businesses_sorted_by_End_Date.csv']

# %% [markdown]
# ## Registered Business Locations
#
# #### Objective:
# Because the end goal for this project is to understand urban planning and distribution of different businesses around San Francisco not all features will be relevent. This will help cut down features that may required more intensive processes to clean.

# %%
# Import Csv
registered_business_locations = pd.read_csv('../data/Businesses/Registered_Business_Locations.csv', low_memory=False)

# %%
# Clean String to Datetime
registered_business_locations['Business Start Date'] = pd.to_datetime(registered_business_locations['Business Start Date'])
registered_business_locations['Business End Date'] = pd.to_datetime(registered_business_locations['Business End Date'])
registered_business_locations['Location Start Date'] = pd.to_datetime(registered_business_locations['Location Start Date'])
registered_business_locations['Location End Date'] = pd.to_datetime(registered_business_locations['Location End Date'])

# Clean Columns
registered_business_locations.columns = [x.lower().replace('-','').replace(' ','_') for x in registered_business_locations.columns]

# %%
registered_business_locations.head(3)
# Out:
#       Location Id  Business Account Number       Ownership Name  \
# 0  0183880-01-001                   183880       Chaname Miriam
# 1  0206570-03-999                   206570  Tower Jonathan Todd
# 2  0302158-01-001                   302158         Hanke Milo F
#
#                       DBA Name    Street Address           City State  \
# 0               Chaname Miriam      3186 23rd St  San Francisco    CA
# 1  Jonathan Tower Construction   6519 Eureka Ave     El+cerrito    CA
# 2                 Milo F Hanke  100 Bush St 1675  San Francisco    CA
#
#    Source Zipcode Business Start Date Business End Date  ... NAICS Code  \
# 0         94110.0          01/01/1989               NaN  ...  8100-8139
# 1         94530.0          07/13/2011        04/19/2017  ...  2300-2399
# 2         94104.0          01/01/1997        08/16/2016  ...  5210-5239
#
#   NAICS Code Description Parking Tax Transient Occupancy Tax LIC Code  \
# 0       Certain Services       False                   False      NaN
# 1           Construction       False                   False      NaN
# 2     Financial Services       False                   False      NaN
#
#   LIC Code Description Supervisor District  \
# 0                  NaN                 9.0
# 1                  NaN                 NaN
# 2                  NaN                 3.0
#
#   Neighborhoods - Analysis Boundaries  Business Corridor  \
# 0                             Mission                NaN
# 1                                 NaN                NaN
# 2      Financial District/South Beach                NaN
#
#                                    Business Location
# 0  3186 23RD ST\nSan Francisco, CA 94110\n(37.753...
# 1  6519 EUREKA AVE\nEL CERRITO, CA 94530\n(37.906...
# 2  100 BUSH ST\nSan Francisco, CA 94104\n(37.7912...
#
# [3 rows x 26 columns]

# %%
registered_business_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227466 entries, 0 to 227465
# Data columns (total 26 columns):
# Location Id                            227466 non-null object
# Business Account Number                227466 non-null int64
# Ownership Name                         227466 non-null object
# DBA Name                               227466 non-null object
# Street Address                         227462 non-null object
# City                                   227273 non-null object
# State                                  226857 non-null object
# Source Zipcode                         227292 non-null float64
# Business Start Date                    227466 non-null datetime64[ns]
# Business End Date                      61277 non-null datetime64[ns]
# Location Start Date                    227466 non-null datetime64[ns]
# Location End Date                      82877 non-null datetime64[ns]
# Mail Address                           166188 non-null object
# Mail City                              168654 non-null object
# Mail Zipcode                           168609 non-null object
# Mail State                             166126 non-null object
# NAICS Code                             136470 non-null object
# NAICS Code Description                 136470 non-null object
# Parking Tax                            227466 non-null bool
# Transient Occupancy Tax                227466 non-null bool
# LIC Code                               13326 non-null object
# LIC Code Description                   12828 non-null object
# Supervisor District                    143372 non-null float64
# Neighborhoods - Analysis Boundaries    143367 non-null object
# Business Corridor                      303 non-null object
# Business Location                      170894 non-null object
# dtypes: bool(2), datetime64[ns](4), float64(2), int64(1), object(17)
# memory usage: 42.1+ MB

# %% [markdown]
# # Total Businesses per Zipcode

# %%
sf_zipcodes = [94102, 94103, 94104, 94105, 94107, 94108, 94109, 94110,\
               94111, 94112, 94114, 94115, 94116, 94117, 94118, 94121,\
               94122, 94123, 94124, 94127, 94129, 94130, 94131, 94132,\
               94133, 94134, 94158]

# %%
# Filter by SF Zipcodes
registered_business_locations = registered_business_locations[registered_business_locations['source_zipcode'].isin(sf_zipcodes)]

# %%
# Groupby Zipcode
business_count_by_zipcode = registered_business_locations.groupby('source_zipcode').count()[['location_id']].reset_index().sort_values('location_id', ascending=False)
business_count_by_zipcode.columns = ['zipcode','number_of_businesses']

# %%
business_count_by_zipcode.head()
# Out:
#    zipcode  number_of_businesses
# 7  94110.0                 15137
# 1  94103.0                 13529
# 4  94107.0                 12102
# 6  94109.0                 11317
# 0  94102.0                  9597

# %%
# Export csv
business_count_by_zipcode.to_csv('../data/Businesses/plot_data/businesses_by_zipcode.csv')

# %% [markdown]
# # Business Types per Zipcode

# %%
# Business types by Zipcode
business_type_by_zipcode = registered_business_locations.groupby(['source_zipcode','naics_code_description']).count()[['state']].unstack()['state']
business_type_by_zipcode
# Out:
# naics_code_description  Accommodations  Administrative and Support Services  \
# source_zipcode
# 94102.0                          326.0                                166.0
# 94103.0                          405.0                                193.0
# 94104.0                           19.0                                248.0
# 94105.0                           40.0                                277.0
# 94107.0                          297.0                                192.0
# 94108.0                          114.0                                102.0
# 94109.0                          364.0                                116.0
# 94110.0                          905.0                                165.0
# 94111.0                           44.0                                223.0
# 94112.0                          288.0                                 95.0
# 94114.0                          574.0                                 82.0
# 94115.0                          259.0                                 69.0
# 94116.0                          182.0                                 34.0
# 94117.0                          489.0                                 74.0
# 94118.0                          207.0                                 85.0
# 94121.0                          218.0                                 63.0
# 94122.0                          341.0                                 70.0
# 94123.0                          241.0                                 65.0
# 94124.0                          104.0                                145.0
# 94127.0                          108.0                                 31.0
# 94129.0                            2.0                                 35.0
# 94130.0                            1.0                                 10.0
# 94131.0                          270.0                                 60.0
# 94132.0                           61.0                                 36.0
# 94133.0                          249.0                                 85.0
# 94134.0                           92.0                                 49.0
# 94158.0                           23.0                                 16.0
#
# naics_code_description  Arts, Entertainment, and Recreation  Certain Services  \
# source_zipcode
# 94102.0                                               340.0             239.0
# 94103.0                                               502.0             279.0
# 94104.0                                                60.0             103.0
# 94105.0                                               122.0             151.0
# 94107.0                                               560.0             244.0
# 94108.0                                               108.0             215.0
# 94109.0                                               344.0             216.0
# 94110.0                                               862.0             270.0
# 94111.0                                                90.0             153.0
# 94112.0                                               230.0             162.0
# 94114.0                                               342.0             106.0
# 94115.0                                               201.0             130.0
# 94116.0                                               198.0              85.0
# 94117.0                                               354.0              82.0
# 94118.0                                               225.0             131.0
# 94121.0                                               232.0              98.0
# 94122.0                                               303.0             162.0
# 94123.0                                               160.0             142.0
# 94124.0                                               217.0             156.0
# 94127.0                                               106.0              66.0
# 94129.0                                                34.0              12.0
# 94130.0                                                17.0               6.0
# 94131.0                                               221.0              55.0
# 94132.0                                                98.0              45.0
# 94133.0                                               265.0             128.0
# 94134.0                                                98.0              83.0
# 94158.0                                                28.0              12.0
#
# naics_code_description  Construction  Financial Services  Food Services  \
# source_zipcode
# 94102.0                        125.0                83.0          696.0
# 94103.0                        290.0               153.0          833.0
# 94104.0                         47.0               583.0          216.0
# 94105.0                         96.0               464.0          435.0
# 94107.0                        256.0               170.0          660.0
# 94108.0                         54.0               164.0          301.0
# 94109.0                        148.0               103.0          603.0
# 94110.0                        477.0               121.0         1000.0
# 94111.0                        105.0               924.0          380.0
# 94112.0                        669.0                46.0          318.0
# 94114.0                        158.0                91.0          357.0
# 94115.0                        128.0                66.0          348.0
# 94116.0                        458.0                64.0          173.0
# 94117.0                        179.0                31.0          362.0
# 94118.0                        249.0                78.0          377.0
# 94121.0                        359.0                46.0          256.0
# 94122.0                        491.0                55.0          446.0
# 94123.0                        103.0               141.0          306.0
# 94124.0                        748.0                23.0          412.0
# 94127.0                        176.0                39.0          103.0
# 94129.0                          6.0                97.0            9.0
# 94130.0                         23.0                 NaN           21.0
# 94131.0                        175.0                41.0          104.0
# 94132.0                        163.0                30.0          203.0
# 94133.0                        107.0               110.0          600.0
# 94134.0                        317.0                15.0          128.0
# 94158.0                         23.0                27.0           72.0
#
# naics_code_description  Information  Insurance  Manufacturing  Multiple  \
# source_zipcode
# 94102.0                       158.0        9.0           44.0     153.0
# 94103.0                       378.0       37.0          216.0     295.0
# 94104.0                       230.0       79.0           24.0      67.0
# 94105.0                       465.0       79.0           32.0     110.0
# 94107.0                       538.0       30.0          235.0     247.0
# 94108.0                       162.0       18.0           35.0     123.0
# 94109.0                        98.0       16.0           31.0     207.0
# 94110.0                       175.0       18.0          166.0     336.0
# 94111.0                       247.0      114.0           46.0      84.0
# 94112.0                        49.0       21.0           45.0     152.0
# 94114.0                       100.0       14.0           21.0     160.0
# 94115.0                        63.0        7.0           25.0     158.0
# 94116.0                        32.0       27.0           24.0      98.0
# 94117.0                        78.0        6.0           58.0     175.0
# 94118.0                        57.0       30.0           38.0     151.0
# 94121.0                        41.0       13.0           38.0     133.0
# 94122.0                        67.0       31.0           47.0     166.0
# 94123.0                        48.0       10.0           16.0     112.0
# 94124.0                        42.0        5.0          294.0     207.0
# 94127.0                        43.0        7.0           15.0      57.0
# 94129.0                        26.0        4.0            7.0      11.0
# 94130.0                         2.0        NaN           14.0      27.0
# 94131.0                        42.0        3.0           20.0      89.0
# 94132.0                        17.0        7.0           14.0      77.0
# 94133.0                       101.0       19.0           21.0     120.0
# 94134.0                        20.0       16.0           26.0      58.0
# 94158.0                        17.0        NaN           14.0      18.0
#
# naics_code_description  Private Education and Health Services  \
# source_zipcode
# 94102.0                                                 544.0
# 94103.0                                                 280.0
# 94104.0                                                 247.0
# 94105.0                                                 167.0
# 94107.0                                                 214.0
# 94108.0                                                 322.0
# 94109.0                                                 486.0
# 94110.0                                                 518.0
# 94111.0                                                 169.0
# 94112.0                                                 164.0
# 94114.0                                                 434.0
# 94115.0                                                 718.0
# 94116.0                                                 206.0
# 94117.0                                                 236.0
# 94118.0                                                 646.0
# 94121.0                                                 168.0
# 94122.0                                                 351.0
# 94123.0                                                 323.0
# 94124.0                                                  59.0
# 94127.0                                                 153.0
# 94129.0                                                  28.0
# 94130.0                                                   1.0
# 94131.0                                                 123.0
# 94132.0                                                 120.0
# 94133.0                                                 116.0
# 94134.0                                                  42.0
# 94158.0                                                  16.0
#
# naics_code_description  Professional, Scientific, and Technical Services  \
# source_zipcode
# 94102.0                                                           1037.0
# 94103.0                                                           1337.0
# 94104.0                                                           1667.0
# 94105.0                                                           1690.0
# 94107.0                                                           1642.0
# 94108.0                                                            884.0
# 94109.0                                                            957.0
# 94110.0                                                           1282.0
# 94111.0                                                           1779.0
# 94112.0                                                            326.0
# 94114.0                                                            922.0
# 94115.0                                                            773.0
# 94116.0                                                            374.0
# 94117.0                                                            646.0
# 94118.0                                                            826.0
# 94121.0                                                            432.0
# 94122.0                                                            640.0
# 94123.0                                                            627.0
# 94124.0                                                            222.0
# 94127.0                                                            384.0
# 94129.0                                                            104.0
# 94130.0                                                             33.0
# 94131.0                                                            480.0
# 94132.0                                                            217.0
# 94133.0                                                            620.0
# 94134.0                                                            130.0
# 94158.0                                                             88.0
#
# naics_code_description  Real Estate and Rental and Leasing Services  \
# source_zipcode
# 94102.0                                                      1042.0
# 94103.0                                                      1526.0
# 94104.0                                                       583.0
# 94105.0                                                       597.0
# 94107.0                                                       956.0
# 94108.0                                                       991.0
# 94109.0                                                      2214.0
# 94110.0                                                      1499.0
# 94111.0                                                       710.0
# 94112.0                                                       418.0
# 94114.0                                                      1076.0
# 94115.0                                                      1169.0
# 94116.0                                                       428.0
# 94117.0                                                      1539.0
# 94118.0                                                      1464.0
# 94121.0                                                      1048.0
# 94122.0                                                      1109.0
# 94123.0                                                      1437.0
# 94124.0                                                       382.0
# 94127.0                                                       320.0
# 94129.0                                                        23.0
# 94130.0                                                         5.0
# 94131.0                                                       462.0
# 94132.0                                                       308.0
# 94133.0                                                      1296.0
# 94134.0                                                       147.0
# 94158.0                                                       216.0
#
# naics_code_description  Retail Trade  Transportation and Warehousing  \
# source_zipcode
# 94102.0                        579.0                           169.0
# 94103.0                       1126.0                           175.0
# 94104.0                        175.0                            20.0
# 94105.0                        220.0                            55.0
# 94107.0                        545.0                           149.0
# 94108.0                        760.0                            46.0
# 94109.0                        687.0                           175.0
# 94110.0                        985.0                           158.0
# 94111.0                        271.0                            32.0
# 94112.0                        459.0                           278.0
# 94114.0                        462.0                            30.0
# 94115.0                        440.0                            82.0
# 94116.0                        196.0                           121.0
# 94117.0                        463.0                            68.0
# 94118.0                        488.0                           114.0
# 94121.0                        291.0                           189.0
# 94122.0                        462.0                           190.0
# 94123.0                        462.0                            26.0
# 94124.0                        446.0                           383.0
# 94127.0                        170.0                            35.0
# 94129.0                         19.0                             6.0
# 94130.0                        125.0                            16.0
# 94131.0                        119.0                            50.0
# 94132.0                        267.0                           102.0
# 94133.0                        676.0                            92.0
# 94134.0                        165.0                           228.0
# 94158.0                         43.0                            25.0
#
# naics_code_description  Utilities  Wholesale Trade
# source_zipcode
# 94102.0                       4.0             72.0
# 94103.0                      12.0            364.0
# 94104.0                       1.0             51.0
# 94105.0                      12.0             81.0
# 94107.0                      13.0            221.0
# 94108.0                       2.0             90.0
# 94109.0                       4.0            104.0
# 94110.0                      14.0            142.0
# 94111.0                       6.0            150.0
# 94112.0                      12.0            113.0
# 94114.0                       NaN             51.0
# 94115.0                       1.0             69.0
# 94116.0                       5.0             86.0
# 94117.0                       1.0             49.0
# 94118.0                       2.0             83.0
# 94121.0                       7.0             74.0
# 94122.0                       3.0            107.0
# 94123.0                       5.0             79.0
# 94124.0                       8.0            319.0
# 94127.0                       3.0             36.0
# 94129.0                       2.0              5.0
# 94130.0                       NaN              2.0
# 94131.0                       1.0             38.0
# 94132.0                       1.0             48.0
# 94133.0                       NaN            114.0
# 94134.0                       4.0             59.0
# 94158.0                       NaN              9.0

# %% [markdown]
# # Businesses Over Time

# %%
# Business Start Dates
business_start = registered_business_locations.groupby([registered_business_locations.business_start_date.dt.year, registered_business_locations.business_start_date.dt.month]).count()[['location_id']]

# Plot Business Start Date
_ = plt.figure(figsize=(12,8))
_ = business_start['location_id'].plot()
_ = plt.title('Business Start Dates', size=15)
_ = plt.xlabel('Dates')
_ = plt.ylabel('Count')

# %%
business_end = registered_business_locations.groupby([registered_business_locations.business_end_date.dt.year, registered_business_locations.business_end_date.dt.month]).count()[['location_id']]

# Plot Dates over Time
_ = plt.figure(figsize=(12,8))
_ = business_end['location_id'].plot()
_ = plt.title('Business End Dates', size=15)
_ = plt.xlabel('Dates')
_ = plt.ylabel('Count')

# %% [markdown]
# # Business Starts

# %%
# Business Started by Year
_ = plt.figure(figsize=(10,6))
_ = registered_business_locations['business_start_date'].dt.year.hist(bins=40)
_ = plt.title('Business Starts by Year', size=15)
_ = plt.xlabel('Year')
_ = plt.ylabel('Number of Businesses')

# Business Started By Month
business_start_month = registered_business_locations.groupby([registered_business_locations.business_start_date.dt.month]).count()[['location_id']]
business_start_month = business_start_month.reset_index()
business_start_month.columns = ['month','count']

_ = plt.figure(figsize=(10,6))
_ = sns.barplot(x='month',y='count',data=business_start_month)
_ = plt.title('Business Starts by Month', size=15)
_ = plt.xlabel('Month')
_ = plt.ylabel('Count')

# %% [markdown]
# # Business Ends

# %%
# Business Ended by Year
_ = plt.figure(figsize=(10,6))
_ = registered_business_locations['business_end_date'].dt.year.hist(bins=40)
_ = plt.title('Business Ended by Year', size=15)
_ = plt.xlabel('Year')
_ = plt.ylabel('Number of Businesses')

# Business Ended By Month
business_end_month = registered_business_locations.groupby([registered_business_locations.business_end_date.dt.month]).count()[['location_id']]
business_end_month = business_end_month.reset_index()
business_end_month.columns = ['month','count']

_ = plt.figure(figsize=(10,6))
_ = sns.barplot(x='month',y='count',data=business_end_month)
_ = plt.title('Business Ended by Month', size=15)
_ = plt.xlabel('Month')
_ = plt.ylabel('Count')

# %% [markdown]
# # Business Life Spans

# %%
# Copy
registered_business_locations = registered_business_locations.copy()

# Fill End Date 
registered_business_locations['business_end_date'] = registered_business_locations['business_end_date'].fillna(datetime.datetime.today())
registered_business_locations['location_end_date'] = registered_business_locations['location_end_date'].fillna(datetime.datetime.today())

# Calculate Durations Months
registered_business_locations['business_duration_m'] = abs(registered_business_locations['business_start_date'] - registered_business_locations['business_end_date'])/np.timedelta64(1, 'M')
registered_business_locations['business_duration_y'] = abs(registered_business_locations['business_start_date'] - registered_business_locations['business_end_date'])/np.timedelta64(1, 'Y')

# %%
# Plot Histogram of Business Durations
_ = plt.figure(figsize=(10,6))
_ = plt.hist(registered_business_locations['business_duration_y'], bins=50)
_ = plt.title('Business Durations', size=15)
_ = plt.xlabel('Time (Years)')
_ = plt.ylabel('Count')

# %%
# Plot Histogram of Business Durations
registered_business_locations.groupby('naics_code_description').mean().sort_values('business_duration_y', ascending=False)[['business_duration_m']]

# 
_ = plt.figure(figsize=(10,6))
_ = plt.hist(registered_business_locations['business_duration_y'], bins=50)
_ = plt.title('Business Durations', size=15)
_ = plt.xlabel('Time (Months)')
_ = plt.ylabel('Count')

# %%
registered_business_locations[['business_duration_y','naics_code_description']].head()
# Out:
#    business_duration_y                            naics_code_description
# 0            32.221727                                  Certain Services
# 2            19.622580                                Financial Services
# 3            19.622580                                Financial Services
# 4            19.288555  Professional, Scientific, and Technical Services
# 5            52.474025                                      Construction

# %%
# Plot Average Business Durations
_ = plt.figure(figsize=(8,10))
_ = sns.boxplot(x='business_duration_y', y='naics_code_description', data=registered_business_locations)
_ = plt.title('Average Business Durations', size=15)
_ = plt.xlabel('Time (Years)')
_ = plt.ylabel('')

# %%
# 
business_df = registered_business_locations.groupby('naics_code_description').mean().sort_values('business_duration_y', ascending=False)[['business_duration_y']].reset_index()
business_df.columns = ['business_type','average_business_duration']

# Plot Average Business Durations
_ = plt.figure(figsize=(8,10))
_ = sns.barplot(x='average_business_duration', y='business_type', data=business_df)
_ = plt.title('Average Business Durations', size=15)
_ = plt.xlabel('Time (Years)')
_ = plt.ylabel('')

# Plot Average Business Durations
_ = plt.figure(figsize=(8,10))
_ = sns.boxplot(x='business_duration_y', y='naics_code_description', data=registered_business_locations)
_ = plt.title('Average Business Durations', size=15)
_ = plt.xlabel('Time (Years)')
_ = plt.ylabel('')

# %% [markdown]
# ## Geolocations

# %%
registered_business_locations[['street_address','city','state','business_location']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186826 entries, 0 to 227465
# Data columns (total 4 columns):
# street_address       186825 non-null object
# city                 186825 non-null object
# state                186810 non-null object
# business_location    143671 non-null object
# dtypes: object(4)
# memory usage: 12.1+ MB

# %%
registered_business_locations.iloc[0]
# Out:
# location_id                                                              0183880-01-001
# business_account_number                                                          183880
# ownership_name                                                           Chaname Miriam
# dba_name                                                                 Chaname Miriam
# street_address                                                             3186 23rd St
# city                                                                      San Francisco
# state                                                                                CA
# source_zipcode                                                                    94110
# business_start_date                                                 1989-01-01 00:00:00
# business_end_date                                            2021-03-22 17:51:25.570606
# location_start_date                                                 1989-01-01 00:00:00
# location_end_date                                            2021-03-22 17:51:25.574040
# mail_address                                                          34 San Felipe Ave
# mail_city                                                           South San Francisco
# mail_zipcode                                                                      94080
# mail_state                                                                           CA
# naics_code                                                                    8100-8139
# naics_code_description                                                 Certain Services
# parking_tax                                                                       False
# transient_occupancy_tax                                                           False
# lic_code                                                                            NaN
# lic_code_description                                                                NaN
# supervisor_district                                                                   9
# neighborhoods__analysis_boundaries                                              Mission
# business_corridor                                                                   NaN
# business_location                     3186 23RD ST\nSan Francisco, CA 94110\n(37.753...
# business_duration_m                                                             386.661
# business_duration_y                                                             32.2217
# Name: 0, dtype: object

# %%
registered_business_locations[['street_address','city','state','business_location']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186826 entries, 0 to 227465
# Data columns (total 4 columns):
# street_address       186825 non-null object
# city                 186825 non-null object
# state                186810 non-null object
# business_location    143671 non-null object
# dtypes: object(4)
# memory usage: 12.1+ MB

# %%
# Get locations with coordinate data
business_addresses_raw = registered_business_locations[registered_business_locations['business_location'].notnull()].copy()

# Get Coordinates from str
business_addresses_raw['coordinates'] = business_addresses_raw['business_location'].str.split('\n').apply(lambda x: x[-1])
business_addresses_raw['city_too'] = business_addresses_raw['business_location'].str.split('\n').apply(lambda x: x[0]).str.lower()

# Clean to addresses with coordinates
business_addresses_pre = business_addresses_raw[business_addresses_raw['coordinates'].str.contains('\(')].copy()

# Str to List
business_addresses_pre['coordinates'] = business_addresses_pre['coordinates'].str.replace('(','').str.replace(')','').str.split(', ')

# Coordinate List to lat lon
business_addresses_pre['lat'] = business_addresses_pre['coordinates'].apply(lambda x: x[0])
business_addresses_pre['lon'] = business_addresses_pre['coordinates'].apply(lambda x: x[1])

# %%
# Merge coordinate list 
registered_business_locations = registered_business_locations.merge(business_addresses_pre[['business_location','city_too','coordinates','lat','lon']], how='left')

# %%
registered_business_locations[['neighborhoods__analysis_boundaries','lat','lon']].head()
# Out:
#   neighborhoods__analysis_boundaries        lat          lon
# 0                            Mission  37.753989  -122.416147
# 1     Financial District/South Beach   37.79128   -122.39995
# 2     Financial District/South Beach   37.79128   -122.39995
# 3     Financial District/South Beach   37.79128   -122.39995
# 4     Financial District/South Beach   37.79128   -122.39995

# %%
registered_business_locations[registered_business_locations['business_location'].isnull()][['street_address','city','state','business_location']]
# Out:
#                        street_address           city state business_location
# 274                    2229 Balboa St  San Francisco    CA               NaN
# 275              2 Townsend St 2-1102  San Francisco    CA               NaN
# 276                    1330 Kobbe Ave  San Francisco    CA               NaN
# 277                     795 Folsom St  San Francisco    CA               NaN
# 278                   225 Velasco Ave  San Francisco    CA               NaN
# 285                           23rd St  San+francisco    CA               NaN
# 291            582 Market St Ste 1111  San Francisco    CA               NaN
# 292                     44 Fredson Ct  San Francisco    CA               NaN
# 293                    981 Mission St  San Francisco    CA               NaN
# 294                    601 4th St 317  San Francisco    CA               NaN
# 295                    981 Mission St  San Francisco    CA               NaN
# 296                     1817 24th Ave  San Francisco    CA               NaN
# 297                     1817 24th Ave  San Francisco    CA               NaN
# 324      2 Embarcadero Center  Fl 8th  San Francisco    CA               NaN
# 325                    570 Chenery St  San Francisco    CA               NaN
# 341                     2187 31st Ave  San Francisco    CA               NaN
# 342                      179 Elsie St  San Francisco    CA               NaN
# 343               455 Eddy St Apt 708  San Francisco    CA               NaN
# 344             185 Clara St Ste 102e  San Francisco    CA               NaN
# 345              158 Juanita Way Bldg  San Francisco    CA               NaN
# 346             1563 La Salle Ave Ave  San Francisco    CA               NaN
# 347                      412 Gaven St  San Francisco    CA               NaN
# 348         1925 Leavenworth St Apt 7  San Francisco    CA               NaN
# 349         2845 Van Ness Ave Apt 504  San Francisco    CA               NaN
# 350             388 Beale St Apt 1610  San Francisco    CA               NaN
# 351             965 Sutter St Ste 619  San Francisco    CA               NaN
# 352              798 Stanyan St Apt 4  San Francisco    CA               NaN
# 353                354 Pine St Fl 5th  San Francisco    CA               NaN
# 354           370 Dorantes Avenue Ave  San Francisco    CA               NaN
# 355                   669 Marina Blvd  San Francisco    CA               NaN
# ...                               ...            ...   ...               ...
# 1961280               1354 Dolores St  San Francisco    CA               NaN
# 1961281      22 Peace Plaza  Unit 533  San+francisco    CA               NaN
# 1961282               50 Alta Mar Way  San Francisco    CA               NaN
# 1961283                 81 Concord St  San Francisco    CA               NaN
# 1961284            1624 California St  San Francisco    CA               NaN
# 1961285            1624 California St  San Francisco    CA               NaN
# 1961286              16th Ave Apt 253  San+francisco    CA               NaN
# 1961287    101 California St Ste 2710  San Francisco    CA               NaN
# 1961288            255 Connecticut St  San Francisco    CA               NaN
# 1961289                3201 Balboa St  San Francisco    CA               NaN
# 1961290              3637 Santiago St  San Francisco    CA               NaN
# 1961291               1448 Willard St  San Francisco    CA               NaN
# 1961292           101 States St Apt 4  San Francisco    CA               NaN
# 1961293                  263 28th Ave  San Francisco    CA               NaN
# 1961294                   274 Pope St  San Francisco    CA               NaN
# 1961295                   274 Pope St  San Francisco    CA               NaN
# 1961296            3200 California St  San Francisco    MO               NaN
# 1961297            61 Bonita St Apt B  San Francisco    CA               NaN
# 1961298                  25 Taylor St  San Francisco    CA               NaN
# 1961299     155 Montgomery St Ste 805  San Francisco    CA               NaN
# 1961300           766 Harrison St 103  San Francisco    CA               NaN
# 1961301                  1075 Post St  San Francisco    CA               NaN
# 1961302               302 Gonzalez Dr  San Francisco    CA               NaN
# 1961303      50 California St Rm 1500  San Francisco    CA               NaN
# 1961304          2101 Pacific Ave 601  San Francisco    CA               NaN
# 1961305        343 Sansome St Ste 600  San Francisco    CA               NaN
# 1961306               253 Brussels St  San Francisco    CA               NaN
# 1961307         1010 Mission St Ste C  San Francisco    CA               NaN
# 1961308               3501 Geary Blvd  San Francisco    CA               NaN
# 1961309        1390 Market St Ste 200  San Francisco    CA               NaN
#
# [43155 rows x 4 columns]

# %%
registered_business_locations['street_address']

# %%
registered_business_locations[registered_business_locations['business_location'].notnull()][['street_address','business_location']]

# %%
registered_business_locations.info()

# %%
# Fix City 
registered_business_locations['city'] = 'San Francisco'

# Combine Address pieces for full address
registered_business_locations['full_address'] = registered_business_locations['street_address'] + ', ' + registered_business_locations['city'] + ', ' + registered_business_locations['state']

# %%
import requests
import json
import time


def search_by_address(query):

    query = "+".join(query.split(" "))

    query_url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=" + query + "&key=" + api_key

    page1 = requests.get(query_url)
    json1 = json.loads(page1.content)

    return json1['results']

def address_to_latlon(address):
    
    query = "+".join(address.split(" "))

    query_url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=" + query + "&key=" + api_key

    page1 = requests.get(query_url)
    json1 = json.loads(page1.content)
    
    latlon = json1['results'][0]['geometry']['location'].values()

    return latlon

# %%
# Reset index
registered_business_locations = registered_business_locations.reset_index(drop = 1)

# %%
registered_business_locations['full_address'][2]
# Out:
# '100 Bush St #1675, San Francisco, CA'

# %%
search_by_address(registered_business_locations['full_address'][2])
# Out:
# []

# %%
registered_business_locations.head()['full_address'].apply(lambda x : search_by_address(x))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-251-cb99a85aebe1> in <module>()
# ----> 1 registered_business_locations.head()['full_address'].apply(lambda x : search_by_address(x))
#
# /anaconda3/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-251-cb99a85aebe1> in <lambda>(x)
# ----> 1 registered_business_locations.head()['full_address'].apply(lambda x : search_by_address(x))
#
# <ipython-input-239-3fd1c28b1f8e> in search_by_address(query)
#      14     json1 = json.loads(page1.content)
#      15
# ---> 16     return json1['results'][0]
#      17
#      18 def address_to_latlon(address):
#
# IndexError: list index out of range

# %% [markdown]
# # By Category

# %%
# Get full dataset where business type is not null
business_by_categories = registered_business_locations[registered_business_locations['naics_code_description'].notnull()]

# %%
business_by_categories.iloc[0]
# Out:
# location_id                                                              0183880-01-001
# business_account_number                                                          183880
# ownership_name                                                           Chaname Miriam
# dba_name                                                                 Chaname Miriam
# street_address                                                             3186 23rd St
# city                                                                      San Francisco
# state                                                                                CA
# source_zipcode                                                                    94110
# business_start_date                                                 1989-01-01 00:00:00
# business_end_date                                                                   NaT
# location_start_date                                                 1989-01-01 00:00:00
# location_end_date                                                                   NaT
# mail_address                                                          34 San Felipe Ave
# mail_city                                                           South San Francisco
# mail_zipcode                                                                      94080
# mail_state                                                                           CA
# naics_code                                                                    8100-8139
# naics_code_description                                                 Certain Services
# parking_tax                                                                       False
# transient_occupancy_tax                                                           False
# lic_code                                                                            NaN
# lic_code_description                                                                NaN
# supervisor_district                                                                   9
# neighborhoods__analysis_boundaries                                              Mission
# business_corridor                                                                   NaN
# business_location                     3186 23RD ST\nSan Francisco, CA 94110\n(37.753...
# business_start_month                                                                  1
# business_start_year                                                                1989
# business_end_month                                                                  NaN
# business_end_year                                                                   NaN
# Name: 0, dtype: object

# %%
business_by_categories['naics_code_description'].value_counts()
# Out:
# Real Estate and Rental and Leasing Services         22968
# Professional, Scientific, and Technical Services    20120
# Retail Trade                                        11103
# Food Services                                        9719
# Private Education and Health Services                6851
# Arts, Entertainment, and Recreation                  6317
# Accommodations                                       6223
# Construction                                         6130
# Financial Services                                   3765
# Multiple                                             3591
# Certain Services                                     3532
# Information                                          3297
# Transportation and Warehousing                       3014
# Administrative and Support Services                  2786
# Wholesale Trade                                      2616
# Manufacturing                                        1566
# Insurance                                             621
# Utilities                                             123
# Name: naics_code_description, dtype: int64

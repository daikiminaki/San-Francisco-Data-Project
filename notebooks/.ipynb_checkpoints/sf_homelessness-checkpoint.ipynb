# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob as glob
import seaborn as sns; sns.set()
#from mpl_toolkits.basemap import Basemap

# %%
# Data about police stations
police_stations = pd.read_csv('Public Safety/Police_Stations__2011_.csv')

# Police Reports 
police_reports_2003_2018 = pd.read_csv('Public Safety/Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv')
police_reports_2018_on = pd.read_csv('Public Safety/Police_Department_Incident_Reports__2018_to_Present.csv')

# Calls
police_call_for_service = pd.read_csv('Public Safety/Police_Department_Calls_for_Service.csv')

# %%
# Clean
police_reports_2018_on.head()
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2018/10/22 10:50:00 AM    2018/10/22         10:50           2018
# 1  2018/08/24 02:50:00 PM    2018/08/24         14:50           2018
# 2  2018/10/14 02:54:00 PM    2018/10/14         14:54           2018
# 3  2018/10/14 02:54:00 PM    2018/10/14         14:54           2018
# 4  2018/10/18 04:40:00 PM    2018/10/18         16:40           2018
#
#   Incident Day of Week         Report Datetime       Row ID  Incident ID  \
# 0               Monday  2018/10/22 11:24:00 AM  72897505073       728975
# 1               Friday  2018/08/24 02:52:00 PM  72925174010       729251
# 2               Sunday  2018/10/24 01:10:00 PM  72980906303       729809
# 3               Sunday  2018/10/24 01:10:00 PM  72980964070       729809
# 4             Thursday  2018/10/26 07:42:00 AM  73011316650       730113
#
#    Incident Number   CAD Number  ...                   Incident Description  \
# ...

# %%
mission = police_reports_2018_on[police_reports_2018_on['Police District'] == 'Mission']

# %%
mission.iloc[0]
# Out:
# Incident Datetime                                2018/06/30 10:10:00 PM
# Incident Date                                                2018/06/30
# Incident Time                                                     22:10
# Incident Year                                                      2018
# Incident Day of Week                                           Saturday
# Report Datetime                                  2018/06/30 10:10:00 PM
# Row ID                                                      73013865050
# Incident ID                                                      730138
# Incident Number                                               180486657
# CAD Number                                                  1.81814e+08
# Report Type Code                                                     IS
# Report Type Description                              Initial Supplement
# Filed Online                                                        NaN
# ...

# %%
# Looking at top Incident Reports
by_incident_code = mission['Incident Description'].value_counts()

# %%
by_incident_code.head(30)
# Out:
# Theft, From Locked Vehicle, >$950                            2430
# Battery                                                       866
# Lost Property                                                 770
# Theft, Other Property, $50-$200                               754
# Mental Health Detention                                       596
# Malicious Mischief, Vandalism to Property                     596
# Traffic Violation Arrest                                      589
# Theft, Other Property, >$950                                  583
# Warrant Arrest, Local SF Warrant                              555
# Vehicle, Stolen, Auto                                         536
# Investigative Detention                                       519
# Warrant Arrest, Enroute To Outside Jurisdiction               510
# Theft, From Unlocked Vehicle, >$950                           508
# Malicious Mischief, Vandalism to Vehicle                      412
# ...

# %%
mission.groupby(['Incident Year','Incident Description']).count()[['Incident Datetime']]
# Out:
#                                                                   Incident Datetime
# Incident Year Incident Description
# 2018          Access Card Information, Theft of                                  10
#               Access Card, Possession of Lost or Stolen, with...                  2
#               Access Card, incl. Credit, Phone, ATM, Fraudule...                109
#               Accessory or Aid Or Harbor Felon                                    1
#               Aided Case                                                        151
# ...                                                                             ...
# 2019          Weapon, Carrying Concealed                                          3
#               Weapon, Carrying Concealed with Felony or Narco...                  1
#               Weapon, Deadly, Imitation or Laser Scope, Exhib...                  8
#               Weapon, Prohibited, Possession, Sale, Mfg., Import                  2
# ...

# %%
_ = plt.figure(figsize=(12,10))
_ = sns.scatterplot(police_reports_2018_on['Latitude'], police_reports_2018_on['Longitude'])

# %%
police_reports_2018_on.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167054 entries, 0 to 167053
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Incident Datetime        167054 non-null  object
#  1   Incident Date            167054 non-null  object
#  2   Incident Time            167054 non-null  object
#  3   Incident Year            167054 non-null  int64
#  4   Incident Day of Week     167054 non-null  object
#  5   Report Datetime          167054 non-null  object
#  6   Row ID                   167054 non-null  int64
#  7   Incident ID              167054 non-null  int64
#  8   Incident Number          167054 non-null  int64
#  9   CAD Number               128868 non-null  float64
#  10  Report Type Code         167054 non-null  object
#  11  Report Type Description  167054 non-null  object
#  12  Filed Online             35945 non-null   object
# ...

# %%
police_reports_2018_on['Incident Subcategory'].value_counts().head(30)
# Out:
# Larceny - From Vehicle           30468
# Other                            23848
# Larceny Theft - Other            12411
# Vandalism                         9337
# Simple Assault                    6428
# Lost Property                     6060
# Motor Vehicle Theft               5681
# Non-Criminal                      5651
# Fraud                             5100
# Recovered Vehicle                 4718
# Drug Violation                    4544
# Aggravated Assault                3398
# Larceny Theft - From Building     3240
# Burglary - Other                  3227
# Suspicious Occ                    2979
# Larceny Theft - Shoplifting       2936
# Warrant                           2859
# Burglary - Residential            2514
# Traffic Violation Arrest          2259
# Missing Person                    2211
# Robbery - Other                   1987
# Intimidation                      1912
# Weapons Offense                   1844
# Missing Adult                     1761
# ...
